# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathulaprasad/Natural-Language-Processing-Assignment_01/blob/main/Assignment_01_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk  
import numpy as np  
import random  
import string
nltk.download('punkt')
# !pip install -U featuretools
import bs4 as bs  
import urllib.request  
import re  
from nltk.util import ngrams

wikipages = [
         'https://en.wikipedia.org/wiki/Rohit_Sharma',
         'https://en.wikipedia.org/wiki/Sachin_Tendulkar', 
         'https://en.wikipedia.org/wiki/Virat_Kohli', 
         'https://en.wikipedia.org/wiki/Sourav_Ganguly',
         'https://en.wikipedia.org/wiki/Sunil_Gavaskar',
          'https://en.wikipedia.org/wiki/Kapil_Dev',
          'https://en.wikipedia.org/wiki/Anil_Kumble',
          'https://en.wikipedia.org/wiki/Dilip_Vengsarkar',
          'https://en.wikipedia.org/wiki/Mohammad_Azharuddin',
          'https://en.wikipedia.org/wiki/MS_Dhoni'
          
         ]
raw_html = ''
article_text = ''         
for wiki in wikipages:
  print("reading wiki  page:" + wiki)
  raw_html = urllib.request.urlopen(wiki)
  #raw_html.join([html_content, raw_html])
  article_html = bs.BeautifulSoup(raw_html, 'lxml')
  article_paragraphs = article_html.find_all('p')
  for para in article_paragraphs:  
    article_text += para.text
    corpus = nltk.sent_tokenize(article_text)
print(len(article_text.split()))
#corpus contains approx. 51234 words!!
tokens = article_text.split()
bigrams = list(ngrams(tokens, 2))
[" ".join(token) for token in bigrams]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already up-to-date: featuretools in /usr/local/lib/python3.7/dist-packages (0.23.2)
# ...
# reading wiki  page:https://en.wikipedia.org/wiki/Rohit_Sharma
# reading wiki  page:https://en.wikipedia.org/wiki/Sachin_Tendulkar
# reading wiki  page:https://en.wikipedia.org/wiki/Virat_Kohli
# reading wiki  page:https://en.wikipedia.org/wiki/Sourav_Ganguly
# reading wiki  page:https://en.wikipedia.org/wiki/Sunil_Gavaskar
# reading wiki  page:https://en.wikipedia.org/wiki/Kapil_Dev
# reading wiki  page:https://en.wikipedia.org/wiki/Anil_Kumble
# reading wiki  page:https://en.wikipedia.org/wiki/Dilip_Vengsarkar
# reading wiki  page:https://en.wikipedia.org/wiki/Mohammad_Azharuddin
# reading wiki  page:https://en.wikipedia.org/wiki/MS_Dhoni
# 51234
# ['Rohit Gurunath',
#  'Gurunath Sharma',
#  'Sharma (born',
#  '(born 30',
#  '30 April',
#  'April 1987)',
#  '1987) is',
# ...

# %%
tokens = article_text.split()
trigrams = list(ngrams(tokens, 3))
[" ".join(token) for token in trigrams]
# Out:
# ['Rohit Gurunath Sharma',
#  'Gurunath Sharma (born',
#  'Sharma (born 30',
#  '(born 30 April',
#  '30 April 1987)',
#  'April 1987) is',
#  '1987) is an',
#  'is an Indian',
#  'an Indian international',
#  'Indian international cricketer',
#  'international cricketer who',
#  'cricketer who plays',
#  'who plays for',
#  'plays for Mumbai',
#  'for Mumbai in',
#  'Mumbai in domestic',
#  'in domestic cricket',
#  'domestic cricket and',
#  'cricket and captains',
#  'and captains Mumbai',
#  'captains Mumbai Indians',
#  'Mumbai Indians in',
#  'Indians in the',
#  'in the Indian',
#  'the Indian Premier',
#  'Indian Premier League',
#  'Premier League as',
#  'League as a',
#  'as a right-handed',
#  'a right-handed batsman',
#  'right-handed batsman and',
#  'batsman and an',
#  'and an occasional',
#  'an occasional right-arm',
#  'occasional right-arm off',
#  'right-arm off break',
#  'off break bowler.',
#  'break bowler. He',
#  'bowler. He is',
#  'He is the',
# ...

# %%
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('punkt')
text = re.sub(r'\[[0-9]*\]',' ',article_text)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)
sentences = nltk.sent_tokenize(text)
print(sentences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os,os.path
mypath= os.path.expanduser('~/nltk_data')
if not os.path.exists(mypath):
  os.mkdir(mypath)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def remove_string_special_characters(s):
  stripped = re.sub('[^a-zA-Z\s)','', s)
  stripped = re.sub('-', '', stripped)
  stripped =re.sub('\s+', ' ', stripped)
  stripped = re.sub('\s+', '', stripped)
  stripped =re.sub('\s+', ' ', stripped)

  stripped= stripped.strip()
  if stripped != '':
    return stripped.lower()

stop_words = set(stopwords.words('english'))
your_list = ['skills', 'ability', 'job', 'description']
for i, line in enumerate(corpus):
  corpus[i] = ' '.join([x for 
                        x in nltk.word_tokenize(line)
                        if(x not in stop_words) and (x not in your_list)])

# %%
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd

vectorizer = CountVectorizer(ngram_range = (2,2))
X1=vectorizer.fit_transform(corpus);
features= vectorizer.get_feature_names()

vectorizer = TfidfVectorizer(ngram_range = (2,2))
X2=vectorizer.fit_transform(corpus);

sums =X2.sum(axis=0)
data=[]
for col, term in enumerate(features):
  data.append((term, sums[0, col]))
  
ranking = pd.DataFrame(data, columns= ['term', 'rank'])
words=ranking.sort_values('rank', ascending = False)
print(words.head(7))
# Out:
#                term       rank
# 22440     world cup  16.169152
# 19178     sri lanka  13.405718
# 22038   west indies  12.900885
# 20396   test series  12.790424
# 19013  south africa  10.148915
# 10658       he also  10.117297
# 15027    odi series   9.663385

# %%
vectorizer = CountVectorizer(ngram_range = (3,3))
X1=vectorizer.fit_transform(corpus);
features= vectorizer.get_feature_names()

vectorizer = TfidfVectorizer(ngram_range = (3,3))
X2=vectorizer.fit_transform(corpus);

sums =X2.sum(axis=0)
data=[]
for col, term in enumerate(features):
  data.append((term, sums[0, col]))
  
ranking = pd.DataFrame(data, columns= ['term', 'rank'])
words=ranking.sort_values('rank', ascending = False)
print(words.head(7))
# Out:
#                         term      rank
# 7930       cricket world cup  7.151540
# 13751  indian premier league  4.119987
# 13698    indian cricket team  3.153726
# 12705   icc champions trophy  3.127292
# 16286       match odi series  3.081395
# 21679       series sri lanka  2.848610
# 15359     leading run scorer  2.636517

# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathulaprasad/Natural-Language-Processing-Assignment_01/blob/main/Assignment_01_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk  
import numpy as np  
import random  
import string
# !nltk.download('punkt')
import bs4 as bs  
import urllib.request  
import re  
from nltk.util import ngrams
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Sachin_Tendulkar')  
raw_html = raw_html.read()
 
article_html = bs.BeautifulSoup(raw_html, 'lxml')
 
article_paragraphs = article_html.find_all('p')
 
article_text = ''
 
for para in article_paragraphs:  
    article_text += para.text
 
corpus = nltk.sent_tokenize(article_text)
print(len(article_text.split()))
tokens = article_text.split()
bigrams = list(ngrams(tokens, 2))
[" ".join(token) for token in bigrams]
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `'punkt''
# /bin/bash: -c: line 0: `nltk.download('punkt')'
# 10086
# ['Sachin Ramesh',
#  'Ramesh Tendulkar',
#  'Tendulkar (/ˌsʌtʃɪn',
#  '(/ˌsʌtʃɪn tɛnˈduːlkər/',
#  'tɛnˈduːlkər/ (listen);',
#  '(listen); born',
#  'born 24',
#  '24 April',
#  'April 1973)',
#  '1973) is',
#  'is an',
#  'an Indian',
#  'Indian former',
#  'former international',
#  'international cricketer',
#  'cricketer who',
#  'who served',
#  'served as',
#  'as captain',
#  'captain of',
#  'of the',
#  'the Indian',
#  'Indian national',
#  'national team.',
#  'team. He',
#  'He is',
#  'is widely',
#  'widely regarded',
#  'regarded as',
#  'as one',
#  'one of',
#  'of the',
#  'the greatest',
#  'greatest batsmen',
#  'batsmen in',
#  'in the',
#  'the history',
#  'history of',
#  'of cricket.[5]',
#  'cricket.[5] He',
#  'He is',
#  'is the',
#  'the highest',
#  'highest run',
#  'run scorer',
#  'scorer of',
#  'of all',
#  'all time',
#  'time in',
#  'in international',
#  'international cricket,',
#  'cricket, and',
#  'and the',
#  'the only',
#  'only player',
#  'player to',
#  'to have',
#  'have scored',
#  'scored one',
#  'one hundred',
#  'hundred international',
#  'international centuries,',
#  'centuries, the',
#  'the first',
#  'first batsman',
#  'batsman to',
#  'to score',
#  'score a',
#  'a double',
#  'double century',
#  'century in',
#  'in a',
#  'a One',
#  'One Day',
#  'Day International',
#  'International (ODI),',
#  '(ODI), the',
#  'the holder',
#  'holder of',
#  'of the',
#  'the record',
#  'record for',
#  'for the',
#  'the most',
#  'most runs',
#  'runs in',
#  'in both',
#  'both Test',
#  'Test and',
#  'and ODI',
#  'ODI cricket,',
#  'cricket, and',
#  'and the',
#  'the only',
#  'only player',
#  'player to',
#  'to complete',
#  'complete more',
#  'more than',
#  'than 30,000',
#  '30,000 runs',
#  'runs in',
#  'in international',
#  'international cricket.[6]',
#  'cricket.[6] In',
#  'In 2013,',
#  '2013, he',
#  'he was',
#  'was the',
#  'the only',
#  'only Indian',
#  'Indian cricketer',
#  'cricketer included',
#  'included in',
#  'in an',
#  'an all-time',
#  'all-time Test',
#  'Test World',
#  'World XI',
#  'XI named',
#  'named to',
#  'to mark',
#  'mark the',
#  'the 150th',
#  '150th anniversary',
#  'anniversary of',
#  'of Wisden',
#  "Wisden Cricketers'",
#  "Cricketers' Almanack.[7][8][9]",
#  'Almanack.[7][8][9] He',
#  'He is',
#  'is affectionately',
#  'affectionately known',
#  'known as',
#  'as Little',
#  'Little Master',
#  'Master or',
#  'or Master',
#  'Master Blaster.[10][11][12][13]',
#  'Blaster.[10][11][12][13] Tendulkar',
#  'Tendulkar took',
#  'took up',
#  'up cricket',
#  'cricket at',
#  'at the',
#  'the age',
#  'age of',
#  'of eleven,',
#  'eleven, made',
#  'made his',
#  'his Test',
#  'Test debut',
#  'debut on',
#  'on 15',
#  '15 November',
#  'November 1989',
#  '1989 against',
#  'against Pakistan',
#  'Pakistan in',
#  'in Karachi',
#  'Karachi at',
#  'at the',
#  'the age',
#  'age of',
#  'of sixteen,',
#  'sixteen, and',
#  'and went',
#  'went on',
#  'on to',
#  'to represent',
#  'represent Mumbai',
#  'Mumbai domestically',
#  'domestically and',
#  'and India',
#  'India internationally',
#  'internationally for',
#  'for close',
#  'close to',
#  'to twenty-four',
#  'twenty-four years.',
#  'years. In',
#  'In 2002,',
#  '2002, halfway',
#  'halfway through',
#  'through his',
#  'his career,',
#  'career, Wisden',
#  "Wisden Cricketers'",
#  "Cricketers' Almanack",
#  'Almanack ranked',
#  'ranked him',
#  'him the',
#  'the second-greatest',
#  'second-greatest Test',
#  'Test batsman',
#  'batsman of',
#  'of all',
#  'all time,',
#  'time, behind',
#  'behind Don',
#  'Don Bradman,',
#  'Bradman, and',
#  'and the',
#  'the second-greatest',
#  'second-greatest ODI',
#  'ODI batsman',
#  'batsman of',
#  'of all',
#  'all time,',
#  'time, behind',
#  'behind Viv',
#  'Viv Richards.[14]',
#  'Richards.[14] Later',
#  'Later in',
#  'in his',
#  'his career,',
#  'career, Tendulkar',
#  'Tendulkar was',
#  'was a',
#  'a part',
#  'part of',
#  'of the',
#  'the Indian',
#  'Indian team',
#  'team that',
#  'that won',
#  'won the',
#  'the 2011',
#  '2011 World',
#  'World Cup,',
#  'Cup, his',
#  'his first',
#  'first win',
#  'win in',
#  'in six',
#  'six World',
#  'World Cup',
#  'Cup appearances',
#  'appearances for',
#  'for India.[15]',
#  'India.[15] He',
#  'He had',
#  'had previously',
#  'previously been',
#  'been named',
#  'named "Player',
#  '"Player of',
#  'of the',
#  'the Tournament"',
#  'Tournament" at',
#  'at the',
#  'the 2003',
#  '2003 edition',
#  'edition of',
#  'of the',
#  'the tournament,',
#  'tournament, held',
#  'held in',
#  'in South',
#  'South Africa.',
#  'Africa. Tendulkar',
#  'Tendulkar received',
#  'received the',
#  'the Arjuna',
#  'Arjuna Award',
#  'Award in',
#  'in 1994',
#  '1994 for',
#  'for his',
#  'his outstanding',
#  'outstanding sporting',
#  'sporting achievement,',
#  'achievement, the',
#  'the Rajiv',
#  'Rajiv Gandhi',
#  'Gandhi Khel',
#  'Khel Ratna',
#  'Ratna award',
#  'award in',
#  'in 1997,',
#  "1997, India's",
#  "India's highest",
#  'highest sporting',
#  'sporting honour,',
#  'honour, and',
#  'and the',
#  'the Padma',
#  'Padma Shri',
#  'Shri and',
#  'and Padma',
#  'Padma Vibhushan',
#  'Vibhushan awards',
#  'awards in',
#  'in 1999',
#  '1999 and',
#  'and 2008,',
#  '2008, respectively,',
#  "respectively, India's",
#  "India's fourth-",
#  'fourth- and',
#  'and second-highest',
#  'second-highest civilian',
#  'civilian awards.[16]',
#  'awards.[16] After',
#  'After a',
#  'a few',
#  'few hours',
#  'hours of',
#  'of his',
#  'his final',
#  'final match',
#  'match on',
#  'on 16',
#  '16 November',
#  'November 2013,',
#  '2013, the',
#  'the Prime',
#  "Prime Minister's",
#  "Minister's Office",
#  'Office announced',
#  'announced the',
#  'the decision',
#  'decision to',
#  'to award',
#  'award him',
#  'him the',
#  'the Bharat',
#  'Bharat Ratna,',
#  "Ratna, India's",
#  "India's highest",
#  'highest civilian',
#  'civilian award.[17][18]',
#  'award.[17][18] He',
#  'He is',
#  'is the',
#  'the youngest',
#  'youngest recipient',
#  'recipient to',
#  'to date',
#  'date and',
#  'and the',
#  'the first',
#  'first ever',
#  'ever sportsperson',
#  'sportsperson to',
#  'to receive',
#  'receive the',
#  'the award.[19][20]',
#  'award.[19][20] He',
#  'He also',
#  'also won',
#  'won the',
#  'the 2010',
#  '2010 Sir',
#  'Sir Garfield',
#  'Garfield Sobers',
#  'Sobers Trophy',
#  'Trophy for',
#  'for cricketer',
#  'cricketer of',
#  'of the',
#  'the year',
#  'year at',
#  'at the',
#  'the ICC',
#  'ICC awards.[21]',
#  'awards.[21] In',
#  'In 2012,',
#  '2012, Tendulkar',
#  'Tendulkar was',
#  'was nominated',
#  'nominated to',
#  'to the',
#  'the Rajya',
#  'Rajya Sabha,',
#  'Sabha, the',
#  'the upper',
#  'upper house',
#  'house of',
#  'of the',
#  'the Parliament',
#  'Parliament of',
#  'of India.[22]',
#  'India.[22] He',
#  'He was',
#  'was also',
#  'also the',
#  'the first',
#  'first sportsperson',
#  'sportsperson and',
#  'and the',
#  'the first',
#  'first person',
#  'person without',
#  'without an',
#  'an aviation',
#  'aviation background',
#  'background to',
#  'to be',
#  'be awarded',
#  'awarded the',
#  'the honorary',
#  'honorary rank',
#  'rank of',
#  'of group',
#  'group captain',
#  'captain by',
#  'by the',
#  'the Indian',
#  'Indian Air',
#  'Air Force.[23]',
#  'Force.[23] In',
#  'In 2012,',
#  '2012, he',
#  'he was',
#  'was named',
#  'named an',
#  'an Honorary',
#  'Honorary Member',
#  'Member of',
#  'of the',
#  'the Order',
#  'Order of',
#  'of Australia.[24][25]',
#  'Australia.[24][25] In',
#  'In 2010,',
#  '2010, Time',
#  'Time magazine',
#  'magazine included',
#  'included Sachin',
#  'Sachin in',
#  'in its',
#  'its annual',
#  'annual Time',
#  'Time 100',
#  '100 list',
#  'list as',
#  'as one',
#  'one of',
#  'of the',
#  'the "Most',
#  '"Most Influential',
#  'Influential People',
#  'People in',
#  'in the',
#  'the World".[26]',
#  'World".[26] In',
#  'In December',
#  'December 2012,',
#  '2012, Tendulkar',
#  'Tendulkar announced',
#  'announced his',
#  'his retirement',
#  'retirement from',
#  'from ODIs.[27]',
#  'ODIs.[27] He',
#  'He retired',
#  'retired from',
#  'from Twenty20',
#  'Twenty20 cricket',
#  'cricket in',
#  'in October',
#  'October 2013[28]',
#  '2013[28] and',
#  'and subsequently',
#  'subsequently retired',
#  'retired from',
#  'from all',
#  'all forms',
#  'forms of',
#  'of cricket',
#  'cricket on',
#  'on 16',
#  '16 November',
#  'November 2013',
#  '2013 after',
#  'after playing',
#  'playing his',
#  'his 200th',
#  '200th Test',
#  'Test match,',
#  'match, against',
#  'against the',
#  'the West',
#  'West Indies',
#  'Indies in',
#  "in Mumbai's",
#  "Mumbai's Wankhede",
#  'Wankhede Stadium.[29]',
#  'Stadium.[29] Tendulkar',
#  'Tendulkar played',
#  'played 664',
#  '664 international',
#  'international cricket',
#  'cricket matches',
#  'matches in',
#  'in total,',
#  'total, scoring',
#  'scoring 34,357',
#  '34,357 runs.[6]',
#  'runs.[6] In',
#  'In 2019,',
#  '2019, Tendulkar',
#  'Tendulkar was',
#  'was inducted',
#  'inducted into',
#  'into the',
#  'the ICC',
#  'ICC Cricket',
#  'Cricket Hall',
#  'Hall of',
#  'of Fame.[30]',
#  'Fame.[30] Tendulkar',
#  'Tendulkar was',
#  'was born',
#  'born at',
#  'at Nirmal',
#  'Nirmal Nursing',
#  'Nursing Home',
#  'Home in',
#  'in Dadar,',
#  'Dadar, Bombay',
#  'Bombay on',
#  'on 24',
#  '24 April',
#  'April 1973',
#  '1973 [31]',
#  '[31] [1][32][33]',
#  '[1][32][33] to',
#  'to a',
#  'a Maharashtrian',
#  'Maharashtrian family.[34][35]',
#  'family.[34][35] His',
#  'His father,',
#  'father, Ramesh',
#  'Ramesh Tendulkar,',
#  'Tendulkar, was',
#  'was a',
#  'a well-known',
#  'well-known Marathi',
#  'Marathi novelist',
#  'novelist &',
#  '& poet',
#  'poet and',
#  'and his',
#  'his mother,',
#  'mother, Rajni,',
#  'Rajni, worked',
#  'worked in',
#  'in the',
#  'the insurance',
#  'insurance industry.[36]',
#  'industry.[36] Ramesh',
#  'Ramesh named',
#  'named Tendulkar',
#  'Tendulkar after',
#  'after his',
#  'his favourite',
#  'favourite music',
#  'music director,',
#  'director, Sachin',
#  'Sachin Dev',
#  'Dev Burman.',
#  'Burman. Tendulkar',
#  'Tendulkar has',
#  'has three',
#  'three elder',
#  'elder siblings:',
#  'siblings: two',
#  'two half-brothers',
#  'half-brothers Nitin',
#  'Nitin and',
#  'and Ajit,',
#  'Ajit, and',
#  'and a',
#  'a half-sister',
#  'half-sister Savita.',
#  'Savita. They',
#  'They were',
#  "were Ramesh's",
#  "Ramesh's children",
#  'children by',
#  'by his',
#  'his first',
#  'first wife,',
#  'wife, who',
#  'who died',
#  'died after',
#  'after the',
#  'the birth',
#  'birth of',
#  'of her',
#  'her third',
#  'third child.[37][38]',
#  'child.[37][38] Tendulkar',
#  'Tendulkar spent',
#  'spent his',
#  'his formative',
#  'formative years',
#  'years in',
#  'in the',
#  'the Sahitya',
#  'Sahitya Sahawas',
#  'Sahawas Cooperative',
#  'Cooperative Housing',
#  'Housing Society',
#  'Society in',
#  'in Bandra',
#  'Bandra (East).',
#  '(East). As',
#  'As a',
#  'a young',
#  'young boy,',
#  'boy, Tendulkar',
#  'Tendulkar was',
#  'was considered',
#  'considered a',
#  'a bully,',
#  'bully, and',
#  'and often',
#  'often picked',
#  'picked up',
#  'up fights',
#  'fights with',
#  'with new',
#  'new children',
#  'children in',
#  'in his',
#  'his school.[39]',
#  'school.[39] He',
#  'He also',
#  'also showed',
#  'showed an',
#  'an interest',
#  'interest in',
#  'in tennis,',
#  'tennis, idolising',
#  'idolising John',
#  'John McEnroe.[40]',
#  'McEnroe.[40] To',
#  'To help',
#  'help curb',
#  'curb his',
#  'his mischievous',
#  'mischievous and',
#  'and bullying',
#  'bullying tendencies,',
#  'tendencies, Ajit',
#  'Ajit introduced',
#  'introduced the',
#  'the young',
#  'young Sachin',
#  'Sachin to',
#  'to cricket',
#  'cricket in',
#  'in 1984.',
#  '1984. He',
#  'He introduced',
#  'introduced him',
#  'him to',
#  'to Ramakant',
#  'Ramakant Achrekar,',
#  'Achrekar, a',
#  'a famous',
#  'famous cricket',
#  'cricket coach',
#  'coach and',
#  'and a',
#  'a club',
#  'club cricketer',
#  'cricketer of',
#  'of repute,',
#  'repute, at',
#  'at Shivaji',
#  'Shivaji Park,',
#  'Park, Dadar.',
#  'Dadar. In',
#  'In the',
#  'the first',
#  'first meeting,',
#  'meeting, the',
#  'the young',
#  'young Sachin',
#  'Sachin did',
#  'did not',
#  'not play',
#  'play his',
#  'his best.',
#  'best. Ajit',
#  'Ajit told',
#  'told Achrekar',
#  'Achrekar that',
#  'that he',
#  'he was',
#  'was feeling',
#  'feeling self-conscious',
#  'self-conscious due',
#  'due to',
#  'to the',
#  'the coach',
#  'coach observing',
#  'observing him,',
#  'him, and',
#  'and was',
#  'was not',
#  'not displaying',
#  'displaying his',
#  'his natural',
#  'natural game.',
#  'game. Ajit',
#  'Ajit requested',
#  'requested the',
#  'the coach',
#  'coach to',
#  'to give',
#  'give him',
#  'him another',
#  'another chance',
#  'chance at',
#  'at playing,',
#  'playing, but',
#  'but watch',
#  'watch while',
#  'while hiding',
#  'hiding behind',
#  'behind a',
#  'a tree.',
#  'tree. This',
#  'This time,',
#  'time, Sachin,',
#  'Sachin, apparently',
#  'apparently unobserved,',
#  'unobserved, played',
#  'played much',
#  'much better',
#  'better and',
#  'and was',
#  'was accepted',
#  'accepted at',
#  "at Achrekar's",
#  "Achrekar's academy.[41]",
#  'academy.[41] Achrekar',
#  'Achrekar was',
#  'was impressed',
#  'impressed with',
#  "with Tendulkar's",
#  "Tendulkar's talent",
#  'talent and',
#  'and advised',
#  'advised him',
#  'him to',
#  'to shift',
#  'shift his',
#  'his schooling',
#  'schooling to',
#  'to Sharadashram',
#  'Sharadashram Vidyamandir',
#  'Vidyamandir (English)',
#  '(English) High',
#  'High School,[1]',
#  'School,[1] a',
#  'a school',
#  'school at',
#  'at Dadar',
#  'Dadar which',
#  'which had',
#  'had a',
#  'a dominant',
#  'dominant cricket',
#  'cricket team',
#  'team and',
#  'and had',
#  'had produced',
#  'produced many',
#  'many notable',
#  'notable cricketers.',
#  'cricketers. Prior',
#  'Prior to',
#  'to this,',
#  'this, Tendulkar',
#  'Tendulkar had',
#  'had attended',
#  'attended the',
#  'the Indian',
#  'Indian Education',
#  "Education Society's",
#  "Society's New",
#  'New English',
#  'English School',
#  'School in',
#  'in Bandra',
#  'Bandra (East).[42]',
#  '(East).[42] He',
#  'He was',
#  'was also',
#  'also coached',
#  'coached under',
#  'under the',
#  'the guidance',
#  'guidance of',
#  'of Achrekar',
#  'Achrekar at',
#  'at Shivaji',
#  'Shivaji Park',
#  'Park in',
#  'in the',
#  'the mornings',
#  'mornings and',
#  'and evenings.[43]',
#  'evenings.[43] Tendulkar',
#  'Tendulkar would',
#  'would practice',
#  'practice for',
#  'for hours',
#  'hours on',
#  'on end',
#  'end in',
#  'in the',
#  'the nets.',
#  'nets. If',
#  'If he',
#  'he became',
#  'became exhausted,',
#  'exhausted, Achrekar',
#  'Achrekar would',
#  'would put',
#  'put a',
#  'a one-rupee',
#  'one-rupee coin',
#  'coin on',
#  'on the',
#  'the top',
#  'top of',
#  'of the',
#  'the stumps,',
#  'stumps, and',
#  'and the',
#  'the bowler',
#  'bowler who',
#  'who dismissed',
#  'dismissed Tendulkar',
#  'Tendulkar would',
#  'would get',
#  'get the',
#  'the coin.',
#  'coin. If',
#  'If Tendulkar',
#  'Tendulkar passed',
#  'passed the',
#  'the whole',
#  'whole session',
#  'session without',
#  'without getting',
#  'getting dismissed,',
#  'dismissed, the',
#  'the coach',
#  'coach would',
#  'would give',
#  'give him',
#  'him the',
#  'the coin.',
#  'coin. Tendulkar',
#  'Tendulkar now',
#  'now considers',
#  'considers the',
#  'the 13',
#  '13 coins',
#  'coins he',
#  'he won',
#  'won then',
#  'then as',
#  'as some',
#  'some of',
#  'of his',
#  'his most',
#  'most prized',
#  'prized possessions.[44]',
#  'possessions.[44] He',
#  'He moved',
#  'moved in',
#  'in with',
#  'with his',
#  'his aunt',
#  'aunt and',
#  'and uncle,',
#  'uncle, who',
#  'who lived',
#  'lived near',
#  'near Shivaji',
#  'Shivaji Park,',
#  'Park, during',
#  'during this',
#  'this period,',
#  'period, due',
#  'due to',
#  'to his',
#  'his hectic',
#  'hectic schedule.[42]',
#  'schedule.[42] Meanwhile,',
#  'Meanwhile, at',
#  'at school,',
#  'school, he',
#  'he developed',
#  'developed a',
#  'a reputation',
#  'reputation as',
#  'as a',
#  'a child',
#  'child prodigy.',
#  'prodigy. He',
#  'He had',
#  'had become',
#  'become a',
#  'a common',
#  'common conversation',
#  'conversation point',
#  'point in',
#  'in local',
#  'local cricketing',
#  'cricketing circles,',
#  'circles, where',
#  'where there',
#  'there were',
#  'were suggestions',
#  'suggestions already',
#  'already that',
#  'that he',
#  'he would',
#  'would become',
#  'become one',
#  'one of',
#  'of the',
#  'the greats.',
#  'greats. Sachin',
#  'Sachin consistently',
#  'consistently featured',
#  'featured in',
#  'in the',
#  'the school',
#  'school team',
#  'team in',
#  'in the',
#  'the Matunga',
#  'Matunga Gujarati',
#  'Gujarati Seva',
#  'Seva Mandal',
#  'Mandal (MGSM)',
#  '(MGSM) Shield.[45]',
#  'Shield.[45] Besides',
#  'Besides school',
#  'school cricket,',
#  'cricket, he',
#  'he also',
#  'also played',
#  'played club',
#  'club cricket,',
#  'cricket, initially',
#  'initially representing',
#  'representing John',
#  'John Bright',
#  'Bright Cricket',
#  'Cricket Club',
#  'Club in',
#  "in Bombay's",
#  "Bombay's premier",
#  'premier club',
#  'club cricket',
#  'cricket tournament,',
#  'tournament, the',
#  'the Kanga',
#  'Kanga League,[42]',
#  'League,[42] and',
#  'and later',
#  'later went',
#  'went on',
#  'on to',
#  'to play',
#  'play for',
#  'for the',
#  'the Cricket',
#  'Cricket Club',
#  'Club of',
#  'of India.[46]',
#  'India.[46] In',
#  'In 1987,',
#  '1987, at',
#  'at the',
#  'the age',
#  'age of',
#  'of 14,',
#  '14, he',
#  'he attended',
#  'attended the',
#  'the MRF',
#  'MRF Pace',
#  'Pace Foundation',
#  'Foundation in',
#  'in Madras',
#  'Madras (now',
#  '(now Chennai)',
#  ...]

# %%
tokens = article_text.split()
trigrams = list(ngrams(tokens, 3))
[" ".join(token) for token in trigrams]
# Out:
# ['Sachin Ramesh Tendulkar',
#  'Ramesh Tendulkar (/ˌsʌtʃɪn',
#  'Tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/',
#  '(/ˌsʌtʃɪn tɛnˈduːlkər/ (listen);',
#  'tɛnˈduːlkər/ (listen); born',
#  '(listen); born 24',
#  'born 24 April',
#  '24 April 1973)',
#  'April 1973) is',
#  '1973) is an',
#  'is an Indian',
#  'an Indian former',
#  'Indian former international',
#  'former international cricketer',
#  'international cricketer who',
#  'cricketer who served',
#  'who served as',
#  'served as captain',
#  'as captain of',
#  'captain of the',
#  'of the Indian',
#  'the Indian national',
#  'Indian national team.',
#  'national team. He',
#  'team. He is',
#  'He is widely',
#  'is widely regarded',
#  'widely regarded as',
#  'regarded as one',
#  'as one of',
#  'one of the',
#  'of the greatest',
#  'the greatest batsmen',
#  'greatest batsmen in',
#  'batsmen in the',
#  'in the history',
#  'the history of',
#  'history of cricket.[5]',
#  'of cricket.[5] He',
#  'cricket.[5] He is',
#  'He is the',
#  'is the highest',
#  'the highest run',
#  'highest run scorer',
#  'run scorer of',
#  'scorer of all',
#  'of all time',
#  'all time in',
#  'time in international',
#  'in international cricket,',
#  'international cricket, and',
#  'cricket, and the',
#  'and the only',
#  'the only player',
#  'only player to',
#  'player to have',
#  'to have scored',
#  'have scored one',
#  'scored one hundred',
#  'one hundred international',
#  'hundred international centuries,',
#  'international centuries, the',
#  'centuries, the first',
#  'the first batsman',
#  'first batsman to',
#  'batsman to score',
#  'to score a',
#  'score a double',
#  'a double century',
#  'double century in',
#  'century in a',
#  'in a One',
#  'a One Day',
#  'One Day International',
#  'Day International (ODI),',
#  'International (ODI), the',
#  '(ODI), the holder',
#  'the holder of',
#  'holder of the',
#  'of the record',
#  'the record for',
#  'record for the',
#  'for the most',
#  'the most runs',
#  'most runs in',
#  'runs in both',
#  'in both Test',
#  'both Test and',
#  'Test and ODI',
#  'and ODI cricket,',
#  'ODI cricket, and',
#  'cricket, and the',
#  'and the only',
#  'the only player',
#  'only player to',
#  'player to complete',
#  'to complete more',
#  'complete more than',
#  'more than 30,000',
#  'than 30,000 runs',
#  '30,000 runs in',
#  'runs in international',
#  'in international cricket.[6]',
#  'international cricket.[6] In',
#  'cricket.[6] In 2013,',
#  'In 2013, he',
#  '2013, he was',
#  'he was the',
#  'was the only',
#  'the only Indian',
#  'only Indian cricketer',
#  'Indian cricketer included',
#  'cricketer included in',
#  'included in an',
#  'in an all-time',
#  'an all-time Test',
#  'all-time Test World',
#  'Test World XI',
#  'World XI named',
#  'XI named to',
#  'named to mark',
#  'to mark the',
#  'mark the 150th',
#  'the 150th anniversary',
#  '150th anniversary of',
#  'anniversary of Wisden',
#  "of Wisden Cricketers'",
#  "Wisden Cricketers' Almanack.[7][8][9]",
#  "Cricketers' Almanack.[7][8][9] He",
#  'Almanack.[7][8][9] He is',
#  'He is affectionately',
#  'is affectionately known',
#  'affectionately known as',
#  'known as Little',
#  'as Little Master',
#  'Little Master or',
#  'Master or Master',
#  'or Master Blaster.[10][11][12][13]',
#  'Master Blaster.[10][11][12][13] Tendulkar',
#  'Blaster.[10][11][12][13] Tendulkar took',
#  'Tendulkar took up',
#  'took up cricket',
#  'up cricket at',
#  'cricket at the',
#  'at the age',
#  'the age of',
#  'age of eleven,',
#  'of eleven, made',
#  'eleven, made his',
#  'made his Test',
#  'his Test debut',
#  'Test debut on',
#  'debut on 15',
#  'on 15 November',
#  '15 November 1989',
#  'November 1989 against',
#  '1989 against Pakistan',
#  'against Pakistan in',
#  'Pakistan in Karachi',
#  'in Karachi at',
#  'Karachi at the',
#  'at the age',
#  'the age of',
#  'age of sixteen,',
#  'of sixteen, and',
#  'sixteen, and went',
#  'and went on',
#  'went on to',
#  'on to represent',
#  'to represent Mumbai',
#  'represent Mumbai domestically',
#  'Mumbai domestically and',
#  'domestically and India',
#  'and India internationally',
#  'India internationally for',
#  'internationally for close',
#  'for close to',
#  'close to twenty-four',
#  'to twenty-four years.',
#  'twenty-four years. In',
#  'years. In 2002,',
#  'In 2002, halfway',
#  '2002, halfway through',
#  'halfway through his',
#  'through his career,',
#  'his career, Wisden',
#  "career, Wisden Cricketers'",
#  "Wisden Cricketers' Almanack",
#  "Cricketers' Almanack ranked",
#  'Almanack ranked him',
#  'ranked him the',
#  'him the second-greatest',
#  'the second-greatest Test',
#  'second-greatest Test batsman',
#  'Test batsman of',
#  'batsman of all',
#  'of all time,',
#  'all time, behind',
#  'time, behind Don',
#  'behind Don Bradman,',
#  'Don Bradman, and',
#  'Bradman, and the',
#  'and the second-greatest',
#  'the second-greatest ODI',
#  'second-greatest ODI batsman',
#  'ODI batsman of',
#  'batsman of all',
#  'of all time,',
#  'all time, behind',
#  'time, behind Viv',
#  'behind Viv Richards.[14]',
#  'Viv Richards.[14] Later',
#  'Richards.[14] Later in',
#  'Later in his',
#  'in his career,',
#  'his career, Tendulkar',
#  'career, Tendulkar was',
#  'Tendulkar was a',
#  'was a part',
#  'a part of',
#  'part of the',
#  'of the Indian',
#  'the Indian team',
#  'Indian team that',
#  'team that won',
#  'that won the',
#  'won the 2011',
#  'the 2011 World',
#  '2011 World Cup,',
#  'World Cup, his',
#  'Cup, his first',
#  'his first win',
#  'first win in',
#  'win in six',
#  'in six World',
#  'six World Cup',
#  'World Cup appearances',
#  'Cup appearances for',
#  'appearances for India.[15]',
#  'for India.[15] He',
#  'India.[15] He had',
#  'He had previously',
#  'had previously been',
#  'previously been named',
#  'been named "Player',
#  'named "Player of',
#  '"Player of the',
#  'of the Tournament"',
#  'the Tournament" at',
#  'Tournament" at the',
#  'at the 2003',
#  'the 2003 edition',
#  '2003 edition of',
#  'edition of the',
#  'of the tournament,',
#  'the tournament, held',
#  'tournament, held in',
#  'held in South',
#  'in South Africa.',
#  'South Africa. Tendulkar',
#  'Africa. Tendulkar received',
#  'Tendulkar received the',
#  'received the Arjuna',
#  'the Arjuna Award',
#  'Arjuna Award in',
#  'Award in 1994',
#  'in 1994 for',
#  '1994 for his',
#  'for his outstanding',
#  'his outstanding sporting',
#  'outstanding sporting achievement,',
#  'sporting achievement, the',
#  'achievement, the Rajiv',
#  'the Rajiv Gandhi',
#  'Rajiv Gandhi Khel',
#  'Gandhi Khel Ratna',
#  'Khel Ratna award',
#  'Ratna award in',
#  'award in 1997,',
#  "in 1997, India's",
#  "1997, India's highest",
#  "India's highest sporting",
#  'highest sporting honour,',
#  'sporting honour, and',
#  'honour, and the',
#  'and the Padma',
#  'the Padma Shri',
#  'Padma Shri and',
#  'Shri and Padma',
#  'and Padma Vibhushan',
#  'Padma Vibhushan awards',
#  'Vibhushan awards in',
#  'awards in 1999',
#  'in 1999 and',
#  '1999 and 2008,',
#  'and 2008, respectively,',
#  "2008, respectively, India's",
#  "respectively, India's fourth-",
#  "India's fourth- and",
#  'fourth- and second-highest',
#  'and second-highest civilian',
#  'second-highest civilian awards.[16]',
#  'civilian awards.[16] After',
#  'awards.[16] After a',
#  'After a few',
#  'a few hours',
#  'few hours of',
#  'hours of his',
#  'of his final',
#  'his final match',
#  'final match on',
#  'match on 16',
#  'on 16 November',
#  '16 November 2013,',
#  'November 2013, the',
#  '2013, the Prime',
#  "the Prime Minister's",
#  "Prime Minister's Office",
#  "Minister's Office announced",
#  'Office announced the',
#  'announced the decision',
#  'the decision to',
#  'decision to award',
#  'to award him',
#  'award him the',
#  'him the Bharat',
#  'the Bharat Ratna,',
#  "Bharat Ratna, India's",
#  "Ratna, India's highest",
#  "India's highest civilian",
#  'highest civilian award.[17][18]',
#  'civilian award.[17][18] He',
#  'award.[17][18] He is',
#  'He is the',
#  'is the youngest',
#  'the youngest recipient',
#  'youngest recipient to',
#  'recipient to date',
#  'to date and',
#  'date and the',
#  'and the first',
#  'the first ever',
#  'first ever sportsperson',
#  'ever sportsperson to',
#  'sportsperson to receive',
#  'to receive the',
#  'receive the award.[19][20]',
#  'the award.[19][20] He',
#  'award.[19][20] He also',
#  'He also won',
#  'also won the',
#  'won the 2010',
#  'the 2010 Sir',
#  '2010 Sir Garfield',
#  'Sir Garfield Sobers',
#  'Garfield Sobers Trophy',
#  'Sobers Trophy for',
#  'Trophy for cricketer',
#  'for cricketer of',
#  'cricketer of the',
#  'of the year',
#  'the year at',
#  'year at the',
#  'at the ICC',
#  'the ICC awards.[21]',
#  'ICC awards.[21] In',
#  'awards.[21] In 2012,',
#  'In 2012, Tendulkar',
#  '2012, Tendulkar was',
#  'Tendulkar was nominated',
#  'was nominated to',
#  'nominated to the',
#  'to the Rajya',
#  'the Rajya Sabha,',
#  'Rajya Sabha, the',
#  'Sabha, the upper',
#  'the upper house',
#  'upper house of',
#  'house of the',
#  'of the Parliament',
#  'the Parliament of',
#  'Parliament of India.[22]',
#  'of India.[22] He',
#  'India.[22] He was',
#  'He was also',
#  'was also the',
#  'also the first',
#  'the first sportsperson',
#  'first sportsperson and',
#  'sportsperson and the',
#  'and the first',
#  'the first person',
#  'first person without',
#  'person without an',
#  'without an aviation',
#  'an aviation background',
#  'aviation background to',
#  'background to be',
#  'to be awarded',
#  'be awarded the',
#  'awarded the honorary',
#  'the honorary rank',
#  'honorary rank of',
#  'rank of group',
#  'of group captain',
#  'group captain by',
#  'captain by the',
#  'by the Indian',
#  'the Indian Air',
#  'Indian Air Force.[23]',
#  'Air Force.[23] In',
#  'Force.[23] In 2012,',
#  'In 2012, he',
#  '2012, he was',
#  'he was named',
#  'was named an',
#  'named an Honorary',
#  'an Honorary Member',
#  'Honorary Member of',
#  'Member of the',
#  'of the Order',
#  'the Order of',
#  'Order of Australia.[24][25]',
#  'of Australia.[24][25] In',
#  'Australia.[24][25] In 2010,',
#  'In 2010, Time',
#  '2010, Time magazine',
#  'Time magazine included',
#  'magazine included Sachin',
#  'included Sachin in',
#  'Sachin in its',
#  'in its annual',
#  'its annual Time',
#  'annual Time 100',
#  'Time 100 list',
#  '100 list as',
#  'list as one',
#  'as one of',
#  'one of the',
#  'of the "Most',
#  'the "Most Influential',
#  '"Most Influential People',
#  'Influential People in',
#  'People in the',
#  'in the World".[26]',
#  'the World".[26] In',
#  'World".[26] In December',
#  'In December 2012,',
#  'December 2012, Tendulkar',
#  '2012, Tendulkar announced',
#  'Tendulkar announced his',
#  'announced his retirement',
#  'his retirement from',
#  'retirement from ODIs.[27]',
#  'from ODIs.[27] He',
#  'ODIs.[27] He retired',
#  'He retired from',
#  'retired from Twenty20',
#  'from Twenty20 cricket',
#  'Twenty20 cricket in',
#  'cricket in October',
#  'in October 2013[28]',
#  'October 2013[28] and',
#  '2013[28] and subsequently',
#  'and subsequently retired',
#  'subsequently retired from',
#  'retired from all',
#  'from all forms',
#  'all forms of',
#  'forms of cricket',
#  'of cricket on',
#  'cricket on 16',
#  'on 16 November',
#  '16 November 2013',
#  'November 2013 after',
#  '2013 after playing',
#  'after playing his',
#  'playing his 200th',
#  'his 200th Test',
#  '200th Test match,',
#  'Test match, against',
#  'match, against the',
#  'against the West',
#  'the West Indies',
#  'West Indies in',
#  "Indies in Mumbai's",
#  "in Mumbai's Wankhede",
#  "Mumbai's Wankhede Stadium.[29]",
#  'Wankhede Stadium.[29] Tendulkar',
#  'Stadium.[29] Tendulkar played',
#  'Tendulkar played 664',
#  'played 664 international',
#  '664 international cricket',
#  'international cricket matches',
#  'cricket matches in',
#  'matches in total,',
#  'in total, scoring',
#  'total, scoring 34,357',
#  'scoring 34,357 runs.[6]',
#  '34,357 runs.[6] In',
#  'runs.[6] In 2019,',
#  'In 2019, Tendulkar',
#  '2019, Tendulkar was',
#  'Tendulkar was inducted',
#  'was inducted into',
#  'inducted into the',
#  'into the ICC',
#  'the ICC Cricket',
#  'ICC Cricket Hall',
#  'Cricket Hall of',
#  'Hall of Fame.[30]',
#  'of Fame.[30] Tendulkar',
#  'Fame.[30] Tendulkar was',
#  'Tendulkar was born',
#  'was born at',
#  'born at Nirmal',
#  'at Nirmal Nursing',
#  'Nirmal Nursing Home',
#  'Nursing Home in',
#  'Home in Dadar,',
#  'in Dadar, Bombay',
#  'Dadar, Bombay on',
#  'Bombay on 24',
#  'on 24 April',
#  '24 April 1973',
#  'April 1973 [31]',
#  '1973 [31] [1][32][33]',
#  '[31] [1][32][33] to',
#  '[1][32][33] to a',
#  'to a Maharashtrian',
#  'a Maharashtrian family.[34][35]',
#  'Maharashtrian family.[34][35] His',
#  'family.[34][35] His father,',
#  'His father, Ramesh',
#  'father, Ramesh Tendulkar,',
#  'Ramesh Tendulkar, was',
#  'Tendulkar, was a',
#  'was a well-known',
#  'a well-known Marathi',
#  'well-known Marathi novelist',
#  'Marathi novelist &',
#  'novelist & poet',
#  '& poet and',
#  'poet and his',
#  'and his mother,',
#  'his mother, Rajni,',
#  'mother, Rajni, worked',
#  'Rajni, worked in',
#  'worked in the',
#  'in the insurance',
#  'the insurance industry.[36]',
#  'insurance industry.[36] Ramesh',
#  'industry.[36] Ramesh named',
#  'Ramesh named Tendulkar',
#  'named Tendulkar after',
#  'Tendulkar after his',
#  'after his favourite',
#  'his favourite music',
#  'favourite music director,',
#  'music director, Sachin',
#  'director, Sachin Dev',
#  'Sachin Dev Burman.',
#  'Dev Burman. Tendulkar',
#  'Burman. Tendulkar has',
#  'Tendulkar has three',
#  'has three elder',
#  'three elder siblings:',
#  'elder siblings: two',
#  'siblings: two half-brothers',
#  'two half-brothers Nitin',
#  'half-brothers Nitin and',
#  'Nitin and Ajit,',
#  'and Ajit, and',
#  'Ajit, and a',
#  'and a half-sister',
#  'a half-sister Savita.',
#  'half-sister Savita. They',
#  'Savita. They were',
#  "They were Ramesh's",
#  "were Ramesh's children",
#  "Ramesh's children by",
#  'children by his',
#  'by his first',
#  'his first wife,',
#  'first wife, who',
#  'wife, who died',
#  'who died after',
#  'died after the',
#  'after the birth',
#  'the birth of',
#  'birth of her',
#  'of her third',
#  'her third child.[37][38]',
#  'third child.[37][38] Tendulkar',
#  'child.[37][38] Tendulkar spent',
#  'Tendulkar spent his',
#  'spent his formative',
#  'his formative years',
#  'formative years in',
#  'years in the',
#  'in the Sahitya',
#  'the Sahitya Sahawas',
#  'Sahitya Sahawas Cooperative',
#  'Sahawas Cooperative Housing',
#  'Cooperative Housing Society',
#  'Housing Society in',
#  'Society in Bandra',
#  'in Bandra (East).',
#  'Bandra (East). As',
#  '(East). As a',
#  'As a young',
#  'a young boy,',
#  'young boy, Tendulkar',
#  'boy, Tendulkar was',
#  'Tendulkar was considered',
#  'was considered a',
#  'considered a bully,',
#  'a bully, and',
#  'bully, and often',
#  'and often picked',
#  'often picked up',
#  'picked up fights',
#  'up fights with',
#  'fights with new',
#  'with new children',
#  'new children in',
#  'children in his',
#  'in his school.[39]',
#  'his school.[39] He',
#  'school.[39] He also',
#  'He also showed',
#  'also showed an',
#  'showed an interest',
#  'an interest in',
#  'interest in tennis,',
#  'in tennis, idolising',
#  'tennis, idolising John',
#  'idolising John McEnroe.[40]',
#  'John McEnroe.[40] To',
#  'McEnroe.[40] To help',
#  'To help curb',
#  'help curb his',
#  'curb his mischievous',
#  'his mischievous and',
#  'mischievous and bullying',
#  'and bullying tendencies,',
#  'bullying tendencies, Ajit',
#  'tendencies, Ajit introduced',
#  'Ajit introduced the',
#  'introduced the young',
#  'the young Sachin',
#  'young Sachin to',
#  'Sachin to cricket',
#  'to cricket in',
#  'cricket in 1984.',
#  'in 1984. He',
#  '1984. He introduced',
#  'He introduced him',
#  'introduced him to',
#  'him to Ramakant',
#  'to Ramakant Achrekar,',
#  'Ramakant Achrekar, a',
#  'Achrekar, a famous',
#  'a famous cricket',
#  'famous cricket coach',
#  'cricket coach and',
#  'coach and a',
#  'and a club',
#  'a club cricketer',
#  'club cricketer of',
#  'cricketer of repute,',
#  'of repute, at',
#  'repute, at Shivaji',
#  'at Shivaji Park,',
#  'Shivaji Park, Dadar.',
#  'Park, Dadar. In',
#  'Dadar. In the',
#  'In the first',
#  'the first meeting,',
#  'first meeting, the',
#  'meeting, the young',
#  'the young Sachin',
#  'young Sachin did',
#  'Sachin did not',
#  'did not play',
#  'not play his',
#  'play his best.',
#  'his best. Ajit',
#  'best. Ajit told',
#  'Ajit told Achrekar',
#  'told Achrekar that',
#  'Achrekar that he',
#  'that he was',
#  'he was feeling',
#  'was feeling self-conscious',
#  'feeling self-conscious due',
#  'self-conscious due to',
#  'due to the',
#  'to the coach',
#  'the coach observing',
#  'coach observing him,',
#  'observing him, and',
#  'him, and was',
#  'and was not',
#  'was not displaying',
#  'not displaying his',
#  'displaying his natural',
#  'his natural game.',
#  'natural game. Ajit',
#  'game. Ajit requested',
#  'Ajit requested the',
#  'requested the coach',
#  'the coach to',
#  'coach to give',
#  'to give him',
#  'give him another',
#  'him another chance',
#  'another chance at',
#  'chance at playing,',
#  'at playing, but',
#  'playing, but watch',
#  'but watch while',
#  'watch while hiding',
#  'while hiding behind',
#  'hiding behind a',
#  'behind a tree.',
#  'a tree. This',
#  'tree. This time,',
#  'This time, Sachin,',
#  'time, Sachin, apparently',
#  'Sachin, apparently unobserved,',
#  'apparently unobserved, played',
#  'unobserved, played much',
#  'played much better',
#  'much better and',
#  'better and was',
#  'and was accepted',
#  'was accepted at',
#  "accepted at Achrekar's",
#  "at Achrekar's academy.[41]",
#  "Achrekar's academy.[41] Achrekar",
#  'academy.[41] Achrekar was',
#  'Achrekar was impressed',
#  'was impressed with',
#  "impressed with Tendulkar's",
#  "with Tendulkar's talent",
#  "Tendulkar's talent and",
#  'talent and advised',
#  'and advised him',
#  'advised him to',
#  'him to shift',
#  'to shift his',
#  'shift his schooling',
#  'his schooling to',
#  'schooling to Sharadashram',
#  'to Sharadashram Vidyamandir',
#  'Sharadashram Vidyamandir (English)',
#  'Vidyamandir (English) High',
#  '(English) High School,[1]',
#  'High School,[1] a',
#  'School,[1] a school',
#  'a school at',
#  'school at Dadar',
#  'at Dadar which',
#  'Dadar which had',
#  'which had a',
#  'had a dominant',
#  'a dominant cricket',
#  'dominant cricket team',
#  'cricket team and',
#  'team and had',
#  'and had produced',
#  'had produced many',
#  'produced many notable',
#  'many notable cricketers.',
#  'notable cricketers. Prior',
#  'cricketers. Prior to',
#  'Prior to this,',
#  'to this, Tendulkar',
#  'this, Tendulkar had',
#  'Tendulkar had attended',
#  'had attended the',
#  'attended the Indian',
#  'the Indian Education',
#  "Indian Education Society's",
#  "Education Society's New",
#  "Society's New English",
#  'New English School',
#  'English School in',
#  'School in Bandra',
#  'in Bandra (East).[42]',
#  'Bandra (East).[42] He',
#  '(East).[42] He was',
#  'He was also',
#  'was also coached',
#  'also coached under',
#  'coached under the',
#  'under the guidance',
#  'the guidance of',
#  'guidance of Achrekar',
#  'of Achrekar at',
#  'Achrekar at Shivaji',
#  'at Shivaji Park',
#  'Shivaji Park in',
#  'Park in the',
#  'in the mornings',
#  'the mornings and',
#  'mornings and evenings.[43]',
#  'and evenings.[43] Tendulkar',
#  'evenings.[43] Tendulkar would',
#  'Tendulkar would practice',
#  'would practice for',
#  'practice for hours',
#  'for hours on',
#  'hours on end',
#  'on end in',
#  'end in the',
#  'in the nets.',
#  'the nets. If',
#  'nets. If he',
#  'If he became',
#  'he became exhausted,',
#  'became exhausted, Achrekar',
#  'exhausted, Achrekar would',
#  'Achrekar would put',
#  'would put a',
#  'put a one-rupee',
#  'a one-rupee coin',
#  'one-rupee coin on',
#  'coin on the',
#  'on the top',
#  'the top of',
#  'top of the',
#  'of the stumps,',
#  'the stumps, and',
#  'stumps, and the',
#  'and the bowler',
#  'the bowler who',
#  'bowler who dismissed',
#  'who dismissed Tendulkar',
#  'dismissed Tendulkar would',
#  'Tendulkar would get',
#  'would get the',
#  'get the coin.',
#  'the coin. If',
#  'coin. If Tendulkar',
#  'If Tendulkar passed',
#  'Tendulkar passed the',
#  'passed the whole',
#  'the whole session',
#  'whole session without',
#  'session without getting',
#  'without getting dismissed,',
#  'getting dismissed, the',
#  'dismissed, the coach',
#  'the coach would',
#  'coach would give',
#  'would give him',
#  'give him the',
#  'him the coin.',
#  'the coin. Tendulkar',
#  'coin. Tendulkar now',
#  'Tendulkar now considers',
#  'now considers the',
#  'considers the 13',
#  'the 13 coins',
#  '13 coins he',
#  'coins he won',
#  'he won then',
#  'won then as',
#  'then as some',
#  'as some of',
#  'some of his',
#  'of his most',
#  'his most prized',
#  'most prized possessions.[44]',
#  'prized possessions.[44] He',
#  'possessions.[44] He moved',
#  'He moved in',
#  'moved in with',
#  'in with his',
#  'with his aunt',
#  'his aunt and',
#  'aunt and uncle,',
#  'and uncle, who',
#  'uncle, who lived',
#  'who lived near',
#  'lived near Shivaji',
#  'near Shivaji Park,',
#  'Shivaji Park, during',
#  'Park, during this',
#  'during this period,',
#  'this period, due',
#  'period, due to',
#  'due to his',
#  'to his hectic',
#  'his hectic schedule.[42]',
#  'hectic schedule.[42] Meanwhile,',
#  'schedule.[42] Meanwhile, at',
#  'Meanwhile, at school,',
#  'at school, he',
#  'school, he developed',
#  'he developed a',
#  'developed a reputation',
#  'a reputation as',
#  'reputation as a',
#  'as a child',
#  'a child prodigy.',
#  'child prodigy. He',
#  'prodigy. He had',
#  'He had become',
#  'had become a',
#  'become a common',
#  'a common conversation',
#  'common conversation point',
#  'conversation point in',
#  'point in local',
#  'in local cricketing',
#  'local cricketing circles,',
#  'cricketing circles, where',
#  'circles, where there',
#  'where there were',
#  'there were suggestions',
#  'were suggestions already',
#  'suggestions already that',
#  'already that he',
#  'that he would',
#  'he would become',
#  'would become one',
#  'become one of',
#  'one of the',
#  'of the greats.',
#  'the greats. Sachin',
#  'greats. Sachin consistently',
#  'Sachin consistently featured',
#  'consistently featured in',
#  'featured in the',
#  'in the school',
#  'the school team',
#  'school team in',
#  'team in the',
#  'in the Matunga',
#  'the Matunga Gujarati',
#  'Matunga Gujarati Seva',
#  'Gujarati Seva Mandal',
#  'Seva Mandal (MGSM)',
#  'Mandal (MGSM) Shield.[45]',
#  '(MGSM) Shield.[45] Besides',
#  'Shield.[45] Besides school',
#  'Besides school cricket,',
#  'school cricket, he',
#  'cricket, he also',
#  'he also played',
#  'also played club',
#  'played club cricket,',
#  'club cricket, initially',
#  'cricket, initially representing',
#  'initially representing John',
#  'representing John Bright',
#  'John Bright Cricket',
#  'Bright Cricket Club',
#  'Cricket Club in',
#  "Club in Bombay's",
#  "in Bombay's premier",
#  "Bombay's premier club",
#  'premier club cricket',
#  'club cricket tournament,',
#  'cricket tournament, the',
#  'tournament, the Kanga',
#  'the Kanga League,[42]',
#  'Kanga League,[42] and',
#  'League,[42] and later',
#  'and later went',
#  'later went on',
#  'went on to',
#  'on to play',
#  'to play for',
#  'play for the',
#  'for the Cricket',
#  'the Cricket Club',
#  'Cricket Club of',
#  'Club of India.[46]',
#  'of India.[46] In',
#  'India.[46] In 1987,',
#  'In 1987, at',
#  '1987, at the',
#  'at the age',
#  'the age of',
#  'age of 14,',
#  'of 14, he',
#  '14, he attended',
#  'he attended the',
#  'attended the MRF',
#  'the MRF Pace',
#  'MRF Pace Foundation',
#  'Pace Foundation in',
#  'Foundation in Madras',
#  'in Madras (now',
#  'Madras (now Chennai)',
#  '(now Chennai) to',
#  ...]

# %%
from gensim.models import Word2Vec
from nltk.corpus import stopwords
nltk.download('punkt')
text = re.sub(r'\[[0-9]*\]',' ',article_text)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)
sentences = nltk.sent_tokenize(text)
print(sentences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [' sachin ramesh tendulkar (/ˌsʌtʃɪn tɛnˈduːlkər/ (listen); born april ) is an indian former international cricketer who served as captain of the indian national team.', 'he is widely regarded as one of the greatest batsmen in the history of cricket.', 'he is the highest run scorer of all time in international cricket, and the only player to have scored one hundred international centuries, the first batsman to score a double century in a one day international (odi), the holder of the record for the most runs in both test and odi cricket, and the only player to complete more than , runs in international cricket.', "in , he was the only indian cricketer included in an all-time test world xi named to mark the th anniversary of wisden cricketers' almanack.", 'he is affectionately known as little master or master blaster.', 'tendulkar took up cricket at the age of eleven, made his test debut on november against pakistan in karachi at the age of sixteen, and went on to represent mumbai domestically and india internationally for close to twenty-four years.', "in , halfway through his career, wisden cricketers' almanack ranked him the second-greatest test batsman of all time, behind don bradman, and the second-greatest odi batsman of all time, behind viv richards.", 'later in his career, tendulkar was a part of the indian team that won the world cup, his first win in six world cup appearances for india.', 'he had previously been named "player of the tournament" at the edition of the tournament, held in south africa.', "tendulkar received the arjuna award in for his outstanding sporting achievement, the rajiv gandhi khel ratna award in , india's highest sporting honour, and the padma shri and padma vibhushan awards in and , respectively, india's fourth- and second-highest civilian awards.", "after a few hours of his final match on november , the prime minister's office announced the decision to award him the bharat ratna, india's highest civilian award.", 'he is the youngest recipient to date and the first ever sportsperson to receive the award.', 'he also won the sir garfield sobers trophy for cricketer of the year at the icc awards.', 'in , tendulkar was nominated to the rajya sabha, the upper house of the parliament of india.', 'he was also the first sportsperson and the first person without an aviation background to be awarded the honorary rank of group captain by the indian air force.', 'in , he was named an honorary member of the order of australia.', 'in , time magazine included sachin in its annual time list as one of the "most influential people in the world".', 'in december , tendulkar announced his retirement from odis.', "he retired from twenty cricket in october and subsequently retired from all forms of cricket on november after playing his th test match, against the west indies in mumbai's wankhede stadium.", 'tendulkar played international cricket matches in total, scoring , runs.', 'in , tendulkar was inducted into the icc cricket hall of fame.', 'tendulkar was born at nirmal nursing home in dadar, bombay on april to a maharashtrian family.', 'his father, ramesh tendulkar, was a well-known marathi novelist & poet and his mother, rajni, worked in the insurance industry.', 'ramesh named tendulkar after his favourite music director, sachin dev burman.', 'tendulkar has three elder siblings: two half-brothers nitin and ajit, and a half-sister savita.', "they were ramesh's children by his first wife, who died after the birth of her third child.", 'tendulkar spent his formative years in the sahitya sahawas cooperative housing society in bandra (east).', 'as a young boy, tendulkar was considered a bully, and often picked up fights with new children in his school.', 'he also showed an interest in tennis, idolising john mcenroe.', 'to help curb his mischievous and bullying tendencies, ajit introduced the young sachin to cricket in .', 'he introduced him to ramakant achrekar, a famous cricket coach and a club cricketer of repute, ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os,os.path
mypath= os.path.expanduser('~/nltk_data')
if not os.path.exists(mypath):
  os.mkdir(mypath)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def remove_string_special_characters(s):
  stripped = re.sub('[^a-zA-Z\s)','', s)
  stripped = re.sub('-', '', stripped)
  stripped =re.sub('\s+', ' ', stripped)
  stripped = re.sub('\s+', '', stripped)
  stripped =re.sub('\s+', ' ', stripped)

  stripped= stripped.strip()
  if stripped != '':
    return stripped.lower()

stop_words = set(stopwords.words('english'))
your_list = ['skills', 'ability', 'job', 'description']
for i, line in enumerate(corpus):
  corpus[i] = ' '.join([x for 
                        x in nltk.word_tokenize(line)
                        if(x not in stop_words) and (x not in your_list)])

# %%
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd

vectorizer = CountVectorizer(ngram_range = (2,2))
X1=vectorizer.fit_transform(corpus);
features= vectorizer.get_feature_names()

vectorizer = TfidfVectorizer(ngram_range = (2,2))
X2=vectorizer.fit_transform(corpus);

sums =X2.sum(axis=0)
data=[]
for col, term in enumerate(features):
  data.append((term, sums[0, col]))
  
ranking = pd.DataFrame(data, columns= ['term', 'rank'])
words=ranking.sort_values('rank', ascending = False)
print(words.head(7))
# Out:
#                   term      rank
# 5280         world cup  4.132436
# 4736  tendulkar scored  3.901374
# 2437           he also  3.425592
# 4475         sri lanka  3.228859
# 2748      india series  2.892917
# 1763     cricket world  2.671691
# 4811       test series  2.619610

# %%
vectorizer = CountVectorizer(ngram_range = (3,3))
X1=vectorizer.fit_transform(corpus);
features= vectorizer.get_feature_names()

vectorizer = TfidfVectorizer(ngram_range = (3,3))
X2=vectorizer.fit_transform(corpus);

sums =X2.sum(axis=0)
data=[]
for col, term in enumerate(features):
  data.append((term, sums[0, col]))
  
ranking = pd.DataFrame(data, columns= ['term', 'rank'])
words=ranking.sort_values('rank', ascending = False)
print(words.head(7))
# Out:
#                            term      rank
# 1747          cricket world cup  2.296026
# 3102         leading run scorer  1.367038
# 1554  citation needed tendulkar  1.307555
# 2572         highest run scorer  1.108101
# 4760         talked 99 hundreds  1.097611
# 3525           nobody talked 99  1.097611
# 3639      one day international  1.073451
